# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.mlab import GaussianKDE
import matplotlib.patheffects as pe
import numpy as np

# %%
import pandas

# %%
all_data = pandas.read_csv("gsr-results-provisional-2023.csv")
all_data_22 = pandas.read_csv("gsr-results-final-2022.csv")

# %%
f, ax = plt.subplots(1,1, dpi=300, figsize=(4,2))
axis = range(60,240,1)
ax.fill_between(axis, 100*GaussianKDE(all_data['Finish Time'])(axis), alpha=0.5, color = 'red', label="2023")
#ax.fill_between(axis, 100*GaussianKDE(all_data_22['Finish Time'])(axis), alpha=0.5, color = 'blue', label="2022")
ax.plot(axis, 100*GaussianKDE(all_data['Finish Time'])(axis), alpha=0.5, color="black", linewidth=1, path_effects=[pe.Stroke(linewidth=1.5, foreground='w'), pe.Normal()])
#ax.plot(axis, 100*GaussianKDE(all_data_22['Finish Time'])(axis), alpha=0.5, color="black", linewidth=1, path_effects=[pe.Stroke(linewidth=1.5, foreground='w'), pe.Normal()])
   
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.set(yticklabels=[])
ax.tick_params(left=False)
ax.grid(False)
f.tight_layout()
f.legend()
ax.set_xlabel("Finish Time (minutes)")

f.savefig("gsr-2023-finish-times.jpg")

# %%
f, ax = plt.subplots(1,1, dpi=300, figsize=(4,2))
axis = range(60,240,1)
ax.fill_between(axis, 100*GaussianKDE(all_data['Finish Time'])(axis), alpha=0.5, color = 'red', label="2023")
ax.fill_between(axis, 100*GaussianKDE(all_data_22['Finish Time'])(axis), alpha=0.5, color = 'blue', label="2022")
ax.plot(axis, 100*GaussianKDE(all_data['Finish Time'])(axis), alpha=0.5, color="black", linewidth=1, path_effects=[pe.Stroke(linewidth=1.5, foreground='w'), pe.Normal()])
ax.plot(axis, 100*GaussianKDE(all_data_22['Finish Time'])(axis), alpha=0.5, color="black", linewidth=1, path_effects=[pe.Stroke(linewidth=1.5, foreground='w'), pe.Normal()])
   
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.set(yticklabels=[])
ax.tick_params(left=False)
ax.grid(False)
f.tight_layout()
f.legend()
ax.set_xlabel("Finish Time (minutes)")

f.savefig("gsr-2022-23-finish-times.jpg")

# %%
f, ax = plt.subplots(1,1, dpi=300, figsize=(4,2))
axis = range(60,240,1)
colors = ["#79C4F2", "#3BBCD9", "#038C8C", "#BDBF7E", "#8C3D20"]
ax.set_prop_cycle('color', colors)
ax.hist(all_data['Finish Time'], bins=axis, alpha=0.5, color = '#79C4F2', label="2023")
#ax.fill_between(axis, 100*GaussianKDE(all_data_22['Finish Time'])(axis), alpha=0.5, color = 'blue', label="2022")
ax.set_facecolor("#003B6B")
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.set(yticklabels=[])
ax.tick_params(left=False)
ax.grid(False)
f.tight_layout()
#leg = f.legend(prop={"size": 6, "family": "Consolas"},)
ax.set_xlabel("Finish Time (minutes)", fontdict={"fontsize": 7, "fontfamily": "Consolas"},
             path_effects=[pe.Stroke(linewidth=1, foreground='w'), pe.Normal()])
ax.set_xticklabels(ax.get_xticklabels(), 
                   path_effects=[pe.Stroke(linewidth=1, foreground='w'), pe.Normal()],
                   fontdict={"fontsize": 6, "fontfamily": "Consolas"},
                   );
f.tight_layout()
f.savefig("gsr-2023-finish-times-hist.png")
# Out:
# /tmp/ipykernel_16930/975510513.py:19: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),

# %%
import matplotlib.ticker as mtick


f, ax = plt.subplots(1,1, dpi=300, figsize=(4,2))

colors = ["#79C4F2", "#3BBCD9", "#038C8C", "#BDBF7E", "#8C3D20"]
ax.set_prop_cycle('color', colors)

axis = range(60,233,1)
ax.hist(all_data['Finish Time'], bins=axis, cumulative=True, density=True, histtype='step', linewidth=1, path_effects=[pe.Stroke(linewidth=1.5, foreground='w'), pe.Normal()], label="2023")
# ax.hist(all_data_22['Finish Time'], bins=axis, cumulative=True, density=True, histtype='step', color="blue", linewidth=1, path_effects=[pe.Stroke(linewidth=1.5, foreground='w'), pe.Normal()], label="2022")
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
#ax.set(yticklabels=[])
#ax.tick_params(left=False)
ax.set_xlim(60, 230)
ax.yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
ax.yaxis.set_minor_formatter(mtick.PercentFormatter(xmax=1))
f.tight_layout()
ax.grid(which="both", axis="x")
ax.set_xlabel("Finish Time (minutes)")
ax.set_ylabel("Percentage finished")

f.legend(loc="center right", prop={"size": 6, "family": "Consolas"})


ax.set_xlabel(ax.get_xlabel(), fontdict={"fontsize": 7, "fontfamily": "Consolas"},
             path_effects=[pe.Stroke(linewidth=1, foreground='w'), pe.Normal()])
ax.set_ylabel(ax.get_ylabel(), fontdict={"fontsize": 7, "fontfamily": "Consolas"},
             path_effects=[pe.Stroke(linewidth=1, foreground='w'), pe.Normal()])
ax.set_xticklabels(ax.get_xticklabels(), 
                   path_effects=[pe.Stroke(linewidth=1, foreground='w'), pe.Normal()],
                   fontdict={"fontsize": 6, "fontfamily": "Consolas"},
                   );
ax.set_yticklabels(ax.get_yticklabels(), 
                   path_effects=[pe.Stroke(linewidth=1, foreground='w'), pe.Normal()],
                   fontdict={"fontsize": 6, "fontfamily": "Consolas"},
                   );
ax.set_facecolor("#003B6B")
f.tight_layout()
    
ax.grid(color='#00111F')

f.savefig("gsr-2023-finish-cumulative.png")
# Out:
# /tmp/ipykernel_16930/4136866499.py:33: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),
# /tmp/ipykernel_16930/4136866499.py:37: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(ax.get_yticklabels(),

# %%
class KentigernPlot:
    def __init__(self, *plotlayout, **kwargs):
        self.colors = ["#79C4F2", "#3BBCD9", "#038C8C", "#BDBF7E", "#8C3D20"]
        self.f, self.ax = plt.subplots(*plotlayout, dpi=300, figsize=kwargs.get("figsize", (3*1.618, 3)))
        for ax in self.f.axes:
            ax.set_prop_cycle('color', self.colors)
        self.f.colors = self.colors
    def __enter__(self):
        return self.f
    def __exit__(self, exc_type, exc_value, exc_tb):
        for ax in self.f.axes:
            ax.set_xlabel(ax.get_xlabel(), fontdict={"fontsize": 7, "fontfamily": "Consolas"},
                                         path_effects=[pe.Stroke(linewidth=1, foreground='w'), pe.Normal()])
            ax.set_ylabel(ax.get_ylabel(), fontdict={"fontsize": 7, "fontfamily": "Consolas"},
                         path_effects=[pe.Stroke(linewidth=1, foreground='w'), pe.Normal()])

            ax.spines['top'].set_visible(False)
            ax.spines['right'].set_visible(False)
            ax.spines['bottom'].set_visible(False)
            ax.spines['left'].set_visible(False)
            for label in ax.get_xticklabels():
                label.set_fontproperties({"size": 6, "family": "Consolas"},)
                label.set_path_effects([pe.Stroke(linewidth=1, foreground='w'), pe.Normal()])
            for label in ax.get_yticklabels():
                label.set_fontproperties({"size": 6, "family": "Consolas"},)
                label.set_path_effects([pe.Stroke(linewidth=1, foreground='w'), pe.Normal()])
            ax.grid(color='white', linewidth=0.15)
            ax.set_facecolor("#003B6B")
        return self.f

# %%
with KentigernPlot(1,1) as f:
    f.axes[0].hist(all_data['Finish Time'], 
                   bins=axis, 
                   cumulative=True, 
                   density=True, 
                   histtype='stepfilled', 
                   linewidth=2, path_effects=[pe.Stroke(linewidth=1.5, foreground='w'), pe.Normal()], label="2023")
    f.axes[0].set_xlabel("Finish Time (minutes)")
    f.axes[0].set_ylabel("Percentage finished")
    
    f.axes[0].set_xlim(60, 230)
    f.axes[0].yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
    f.axes[0].yaxis.set_minor_formatter(mtick.PercentFormatter(xmax=1))

# %%
ax.yaxis.grid()

# %%
import matplotlib.ticker as mtick


f, ax = plt.subplots(1,1, dpi=300, figsize=(4,2))
axis = range(60,233,1)
ax.hist(all_data['Finish Time'], bins=axis, cumulative=True, density=True, histtype='step', color="red", linewidth=1, path_effects=[pe.Stroke(linewidth=1.5, foreground='w'), pe.Normal()], label="2023")
ax.hist(all_data_22['Finish Time'], bins=axis, cumulative=True, density=True, histtype='step', color="blue", linewidth=1, path_effects=[pe.Stroke(linewidth=1.5, foreground='w'), pe.Normal()], label="2022")
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
#ax.set(yticklabels=[])
#ax.tick_params(left=False)
ax.grid(which="both", axis="x")
ax.set_xlim(60, 230)
ax.yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
ax.yaxis.set_minor_formatter(mtick.PercentFormatter(xmax=1))
f.tight_layout()

ax.set_xlabel("Finish Time (minutes)")
ax.set_ylabel("Percentage finished")

f.legend(loc="center right")

f.savefig("gsr-2022-finish-cumulative.jpg")

# %% [markdown]
# ## Clubs

# %%
non_club = all_data[all_data['Club'].isna()]
club = all_data[~all_data['Club'].isna()]

# %%
f, axes = plt.subplots(1,2, dpi=300, figsize=(4,2))
axis = range(60,240,1)
ax = axes[0]
ax.fill_between(axis, 100*GaussianKDE(club['Finish Time'])(axis), alpha=0.5, color = 'red', label="In club")
ax.fill_between(axis, 100*GaussianKDE(non_club['Finish Time'])(axis), alpha=0.5, color = 'blue', label="No club")
ax.plot(axis, 100*GaussianKDE(club['Finish Time'])(axis), alpha=0.5, color="black", linewidth=1, path_effects=[pe.Stroke(linewidth=1.5, foreground='w'), pe.Normal()])
ax.plot(axis, 100*GaussianKDE(non_club['Finish Time'])(axis), alpha=0.5, color="black", linewidth=1, path_effects=[pe.Stroke(linewidth=1.5, foreground='w'), pe.Normal()])
   
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.set(yticklabels=[])
ax.tick_params(left=False)
ax.grid(False)
ax.set_xlabel("Finish Time (minutes)")

ax = axes[1]

ax.hist(club['Finish Time'], bins=axis, cumulative=True, density=True, histtype='step', color="red", linewidth=1, path_effects=[pe.Stroke(linewidth=1.5, foreground='w'), pe.Normal()])
ax.hist(non_club['Finish Time'], bins=axis, cumulative=True, density=True, histtype='step', color="blue", linewidth=1, path_effects=[pe.Stroke(linewidth=1.5, foreground='w'), pe.Normal()])
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
#ax.set(yticklabels=[])
#ax.tick_params(left=False)
ax.grid(which="both", axis="x")
ax.set_xlim(60, 230)
ax.yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
ax.yaxis.set_minor_formatter(mtick.PercentFormatter(xmax=1))
f.tight_layout()

ax.set_xlabel("Finish Time (minutes)")
ax.set_ylabel("Percentage finished")


f.tight_layout()
f.legend(loc="center right")
ax.set_xlabel("Finish Time (minutes)")

f.savefig("gsr-club-no-club.jpg")

# %%
quantiles = pandas.DataFrame()

# %%
quantiles = pandas.DataFrame()
quantiles['club'] = club.quantile(q=np.linspace(0.05,1,20))['Finish Time']
quantiles['non club'] = non_club.quantile(q=np.linspace(0.05,1,20))['Finish Time']
quantiles['overall'] = all_data.quantile(q=np.linspace(0.05,1,20))['Finish Time']

# %%
print(quantiles.to_markdown())
# Out:
# |      |     club |   non club |   overall |
# |-----:|---------:|-----------:|----------:|
# | 0.05 |  78.6167 |    93.9833 |   90.7167 |
# | 0.1  |  84.1167 |    99.15   |   96.63   |
# | 0.15 |  88.6033 |   103.058  |  100.645  |
# | 0.2  |  92.7167 |   106.85   |  104.433  |
# | 0.25 |  95.7583 |   109.579  |  107.85   |
# | 0.3  |  98.41   |   112.35   |  110.467  |
# | 0.35 | 101.195  |   114.721  |  113.2    |
# | 0.4  | 104.293  |   116.983  |  115.57   |
# | 0.45 | 107.492  |   119.367  |  117.933  |
# | 0.5  | 110.15   |   122.05   |  120.5    |
# | 0.55 | 113.183  |   125.117  |  123.617  |
# | 0.6  | 115.887  |   127.883  |  126.647  |
# | 0.65 | 119.137  |   130.883  |  129.6    |
# | 0.7  | 123.543  |   134.533  |  133.067  |
# | 0.75 | 128.183  |   138.233  |  137.258  |
# | 0.8  | 132.577  |   142.367  |  141.58   |
# | 0.85 | 139.58   |   147.317  |  146.65   |
# | 0.9  | 148.303  |   155.25   |  154.437  |
# | 0.95 | 161.19   |   167.721  |  166.933  |
# ...

# %%
print(non_club.quantile(q=np.linspace(0.05,1,20))['Finish Time'].to_markdown())
# Out:
# |      |   Finish Time |
# |-----:|--------------:|
# | 0.05 |       93.9833 |
# | 0.1  |       99.15   |
# | 0.15 |      103.058  |
# | 0.2  |      106.85   |
# | 0.25 |      109.579  |
# | 0.3  |      112.35   |
# | 0.35 |      114.721  |
# | 0.4  |      116.983  |
# | 0.45 |      119.367  |
# | 0.5  |      122.05   |
# | 0.55 |      125.117  |
# | 0.6  |      127.883  |
# | 0.65 |      130.883  |
# | 0.7  |      134.533  |
# | 0.75 |      138.233  |
# | 0.8  |      142.367  |
# | 0.85 |      147.317  |
# | 0.9  |      155.25   |
# | 0.95 |      167.721  |
# | 1    |      229.933  |

# %% [markdown]
# ## Percentiles

# %%
print(all_data.quantile(q=np.linspace(0.05,1,20))['Finish Time'].to_markdown())
# Out:
# |      |   Finish Time |
# |-----:|--------------:|
# | 0.05 |       90.7167 |
# | 0.1  |       96.63   |
# | 0.15 |      100.645  |
# | 0.2  |      104.433  |
# | 0.25 |      107.85   |
# | 0.3  |      110.467  |
# | 0.35 |      113.2    |
# | 0.4  |      115.57   |
# | 0.45 |      117.933  |
# | 0.5  |      120.5    |
# | 0.55 |      123.617  |
# | 0.6  |      126.647  |
# | 0.65 |      129.6    |
# | 0.7  |      133.067  |
# | 0.75 |      137.258  |
# | 0.8  |      141.58   |
# | 0.85 |      146.65   |
# | 0.9  |      154.437  |
# | 0.95 |      166.933  |
# | 1    |      231.733  |

# %%
percentiles, times, _ = ax.hist(all_data_22['Finish Time'], bins=axis, cumulative=True, density=True, histtype='step', color="black", linewidth=1, path_effects=[pe.Stroke(linewidth=1.5, foreground='w'), pe.Normal()])

# %%
percentiles[30], times[30]
# Out:
# (0.055440224691659545, 90)

# %%
percentiles, times, _ = ax.hist(all_data['Finish Time'], bins=axis, cumulative=True, density=True, histtype='step', color="black", linewidth=1, path_effects=[pe.Stroke(linewidth=1.5, foreground='w'), pe.Normal()])

# %%
percentiles[30], times[30]
# Out:
# (0.051439696690234654, 90)
